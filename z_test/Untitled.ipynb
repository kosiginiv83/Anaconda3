# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import math
import operator

from pprint import pprint

# %matplotlib inline

# %%
def prepare_data(file):
    date = []
    value = []
    with open(file, encoding='utf-8') as f:
        for line in f:
            line_list = line.split(';')
            date.append(line_list[0])
            value.append(line_list[1].strip())

    date.remove('Date')
    value.remove('Our_L')

    value_int = list(map(int, value))
    date_time = list(map(lambda x: time.strptime(date[x], '%d/%m/%Y %H:%M'), range(len(date))))

    data_df = pd.DataFrame({
        'date': date_time,
        'value': value
    })
    
    return data_df

# %%
a = time.strptime('05-02-17 22:00', '%d-%m-%y %H:%M')
print(a)
print(a.tm_wday)
len(benchmark_df)
# Out:
# time.struct_time(tm_year=2017, tm_mon=2, tm_mday=5, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=36, tm_isdst=-1)
# 6
# 5389

# %%
data_df = prepare_data('Benchmark.txt')

dpi = 80
fig = plt.figure(dpi = dpi, figsize = (1240 / dpi, 512 / dpi))
date_s = list(map(lambda x: time.mktime(data_df.iloc[x]['date']), range(len(data_df))))
plt.plot(date_s, data_df['value'])
xaxe_ticks = [time.mktime(data_df.iloc[i]['date']) for i in \
              range(len(data_df)) if data_df.iloc[i]['date'][6] == 6]
ax = fig.gca()
ax.set_xticks(xaxe_ticks)
plt.grid(axis='x')
plt.show()

# %%
sliced_benchmark_df = data_df[3500:4100]

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (1240 / dpi, 512 / dpi))
date_s = list(map(lambda x: time.mktime(sliced_benchmark_df.iloc[x]['date']), range(len(sliced_benchmark_df))))
plt.plot(date_s, sliced_benchmark_df['value'], color='red', linestyle='dashed')

#print(sliced_benchmark_df[8:11], '\n')
#print(sliced_benchmark_df[8:11]['date'], '\n')
#print(sliced_benchmark_df.iloc[0]['date'], '\n')
#print(time.mktime(sliced_benchmark_df.iloc[0]['date']), '\n')
#print(sliced_benchmark_df.iloc[0]['date'])
#print(sliced_benchmark_df.iloc[0]['date'][6])

xaxe_ticks = [time.mktime(sliced_benchmark_df.iloc[i]['date']) for i in \
              range(len(sliced_benchmark_df)) if sliced_benchmark_df.iloc[i]['date'][6] == 6]
ax = fig.gca()
ax.set_xticks(xaxe_ticks)
plt.grid(axis='x')

plt.show()

# %%
data_df = prepare_data('Data\SetID 100.txt')

dpi = 80
fig = plt.figure(dpi = dpi, figsize = (1240 / dpi, 512 / dpi))
date_s = list(map(lambda x: time.mktime(data_df.iloc[x]['date']), range(len(data_df))))
plt.plot(date_s, data_df['value'])
xaxe_ticks = [time.mktime(data_df.iloc[i]['date']) for i in \
              range(len(data_df)) if data_df.iloc[i]['date'][6] == 6]
ax = fig.gca()
ax.set_xticks(xaxe_ticks)
plt.grid(axis='x')
plt.show()

# %%
sliced_benchmark_df = data_df[3500:4100]

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (1240 / dpi, 512 / dpi))
date_s = list(map(lambda x: time.mktime(sliced_benchmark_df.iloc[x]['date']), range(len(sliced_benchmark_df))))
plt.plot(sliced_benchmark_df, color='red', linestyle='solid')

xaxe_ticks = [time.mktime(sliced_benchmark_df.iloc[i]['date']) for i in \
              range(len(sliced_benchmark_df)) if sliced_benchmark_df.iloc[i]['date'][6] == 6]
ax = fig.gca()
ax.set_xticks(xaxe_ticks)
plt.grid(axis='x')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-203-fbbe8e83566b> in <module>()
#       2 fig = plt.figure(dpi = dpi, figsize = (1240 / dpi, 512 / dpi))
#       3 date_s = list(map(lambda x: time.mktime(sliced_benchmark_df.iloc[x]['date']), range(len(sliced_benchmark_df))))
# ----> 4 plt.plot(sliced_benchmark_df, color='red', linestyle='solid')
#       5
#       6 xaxe_ticks = [time.mktime(sliced_benchmark_df.iloc[i]['date']) for i in               range(len(sliced_benchmark_df)) if sliced_benchmark_df.iloc[i]['date'][6] == 6]
#
# C:\Anaconda_pf\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3238                       mplDeprecation)
#    3239     try:
# -> 3240         ret = ax.plot(*args, **kwargs)
#    3241     finally:
#    3242         ax._hold = washold
#
# ...

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (1240 / dpi, 512 / dpi))
date_s = list(map(lambda x: time.mktime(sliced_benchmark_df.iloc[x]['date']), range(len(sliced_benchmark_df))))
plt.plot(date_s, sliced_benchmark_df['value'], color='red', linestyle='solid')

rolling_mean = sliced_benchmark_df['value'].rolling(window=24).mean()
plt.title("Moving average\n window size = {}".format(24))
plt.plot(date_s, rolling_mean, "g", label="Rolling mean trend")

xaxe_ticks = [time.mktime(sliced_benchmark_df.iloc[i]['date']) for i in \
              range(len(sliced_benchmark_df)) if sliced_benchmark_df.iloc[i]['date'][6] == 6]
ax = fig.gca()
ax.set_xticks(xaxe_ticks)
plt.grid(axis='x')

plt.show()

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (1240 / dpi, 512 / dpi))
date_s = list(map(lambda x: time.mktime(data_df.iloc[x]['date']), range(len(data_df))))
plt.plot(date_s, data_df['value'], color='red', linestyle='solid')

rolling_mean = data_df['value'].rolling(window=12).mean()
plt.title("Moving average\n window size = {}".format(24))
plt.plot(date_s, rolling_mean, "g", label="Rolling mean trend")

xaxe_ticks = [time.mktime(data_df.iloc[i]['date']) for i in \
              range(len(data_df)) if data_df.iloc[i]['date'][6] == 6]
ax = fig.gca()
ax.set_xticks(xaxe_ticks)
plt.grid(axis='x')

plt.show()
