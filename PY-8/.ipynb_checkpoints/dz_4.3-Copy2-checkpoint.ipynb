# %% [markdown]
# В файле должны быть сохранены результаты запуска на тестовых данных.
#
# Дано: API для данных о футбольных матчах и командах.
#
# Используя kmeans сделать кластеризацию футбольных команд по среднему возрасту игроков команды и количеству проигрышей, результат отобразить в виде точечного графика для случая из 3 и из 5 кластеров.

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.vq import whiten, kmeans2
from pprint import pprint
import datetime
import math
# %matplotlib inline

# %%
def call_api(uri, result_key):
    json = {}
    try:
        json = requests.get(uri, headers={'X-Auth-Token': '156809c82dae43b2b24c75429b9140ed'}).json()
        return json[result_key]
    except:
        print(json)
        return None

# %%
teams = call_api('http://api.football-data.org/v1/soccerseasons/439/teams', 'teams')
teams
# Out:
# [{'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/496/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/496/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/496'}},
#   'code': None,
#   'crestUrl': 'http://upload.wikimedia.org/wikipedia/de/6/63/Rio_Ave_FC.svg',
#   'name': 'FC Rio Ave',
#   'shortName': 'Rio Ave',
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/503/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/503/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/503'}},
#   'code': 'FCP',
#   'crestUrl': 'http://upload.wikimedia.org/wikipedia/de/e/ed/FC_Porto_1922-2005.svg',
#   'name': 'FC Porto',
#   'shortName': 'Porto',
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/583/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/583/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/583'}},
#   'code': None,
#   'crestUrl': 'https://upload.wikimedia.org/wikipedia/pt/8/8c/Logo_Moreirense.svg',
#   'name': 'Moreirense FC',
#   'shortName': 'Moreirense',
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/507/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/507/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/507'}},
#   'code': None,
#   'crestUrl': 'http://upload.wikimedia.org/wikipedia/de/f/f2/FC_Pacos_de_Ferreira.svg',
#   'name': 'FC Paços de Ferreira',
#   'shortName': 'Ferreira',
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/498/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/498/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/498'}},
#   'code': 'SCP',
#   'crestUrl': 'https://upload.wikimedia.org/wikipedia/en/3/3e/Sporting_Clube_de_Portugal.png',
#   'name': 'Sporting CP',
#   'shortName': 'Sporting',
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/504/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/504/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/504'}},
#   'code': None,
#   'crestUrl': 'http://upload.wikimedia.org/wikipedia/de/3/3b/Marítimo_Funchal.svg',
#   'name': 'Maritimo Funchal',
#   'shortName': 'M Funchal',
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/1049/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/1049/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/1049'}},
#   'code': None,
#   'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/f/fc/Emblema_CD_Tondela.png',
#   'name': 'CD Tondela',
#   'shortName': 'Tondela',
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/495/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/495/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/495'}},
#   'code': 'SLB',
#   'crestUrl': 'http://upload.wikimedia.org/wikipedia/de/8/89/Logo_Benfica_Lissabon.svg',
#   'name': 'SL Benfica',
#   'shortName': 'Lisbon',
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/810/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/810/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/810'}},
#   'code': None,
#   'crestUrl': 'http://upload.wikimedia.org/wikipedia/en/4/40/Boavista_F.C._logo.svg',
#   'name': 'Boavista Porto FC',
#   'shortName': 'Boavista',
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/712/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/712/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/712'}},
#   'code': None,
#   'crestUrl': 'http://upload.wikimedia.org/wikipedia/de/b/b4/FC_Arouca.png',
#   'name': 'FC Arouca',
#   'shortName': 'Arouca',
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/506/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/506/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/506'}},
#   'code': None,
#   'crestUrl': 'http://upload.wikimedia.org/wikipedia/de/b/bd/Vitória_Setúbal.svg',
#   'name': 'Vitoria Setubal',
#   'shortName': 'Setubal',
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/711/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/711/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/711'}},
#   'code': None,
#   'crestUrl': 'http://upload.wikimedia.org/wikipedia/de/d/db/Belenenses_Lissabon.svg',
#   'name': 'C.F. Os Belenenses',
#   'shortName': 'B. Lisbon',
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/502/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/502/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/502'}},
#   'code': None,
#   'crestUrl': 'http://upload.wikimedia.org/wikipedia/de/8/81/Vitoria_Guimaraes.svg',
#   'name': 'Vitoria Guimaraes',
#   'shortName': 'Guimares',
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/497/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/497/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/497'}},
#   'code': None,
#   'crestUrl': 'http://upload.wikimedia.org/wikipedia/de/f/f3/Sporting_Clube_de_Braga.svg',
#   'name': 'Sporting Braga',
#   'shortName': 'Braga',
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/582/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/582/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/582'}},
#   'code': None,
#   'crestUrl': 'http://upload.wikimedia.org/wikipedia/de/1/14/GD_Estoril_Praia.svg',
#   'name': 'GD Estoril Praia',
#   'shortName': 'Estoril',
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/500/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/500/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/500'}},
#   'code': None,
#   'crestUrl': None,
#   'name': 'Feirense',
#   'shortName': None,
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/501/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/501/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/501'}},
#   'code': None,
#   'crestUrl': 'http://upload.wikimedia.org/wikipedia/de/e/ee/Nacional_Funchal.svg',
#   'name': 'Nacional Funchal',
#   'shortName': 'Funchal',
#   'squadMarketValue': None},
#  {'_links': {'fixtures': {'href': 'http://api.football-data.org/v1/teams/1103/fixtures'},
#    'players': {'href': 'http://api.football-data.org/v1/teams/1103/players'},
#    'self': {'href': 'http://api.football-data.org/v1/teams/1103'}},
#   'code': None,
#   'crestUrl': 'https://upload.wikimedia.org/wikipedia/en/0/05/G_D_Chaves.png',
#   'name': 'G.D. Chaves',
#   'shortName': 'Chaves',
#   'squadMarketValue': None}]

# %%
for team in teams:
    players = call_api(team['_links']['players']['href'], 'players')
    fixtures = call_api(team['_links']['fixtures']['href'], 'fixtures')
    goals = 0
    for f in fixtures:
        if team['name'] == f['homeTeamName']:
            goals += f['result']['goalsHomeTeam'] if f['result']['goalsHomeTeam'] else 0
        else:
            goals += f['result']['goalsAwayTeam'] if f['result']['goalsAwayTeam'] else 0
    print('Team "{}", {} players, {} goals'.format(team['name'], len(players), goals))
    team['players'] = players
    team['goals'] = goals
    
pprint(fixtures)
pprint(players)
# Out:
# Team "FC Rio Ave", 27 players, 11 goals
# Team "FC Porto", 25 players, 39 goals
# Team "Moreirense FC", 28 players, 7 goals
# Team "FC Paços de Ferreira", 26 players, 13 goals
# Team "Sporting CP", 27 players, 29 goals
# Team "Maritimo Funchal", 29 players, 13 goals
# Team "CD Tondela", 27 players, 15 goals
# Team "SL Benfica", 31 players, 24 goals
# Team "Boavista Porto FC", 37 players, 12 goals
# Team "FC Arouca", 22 players, 0 goals
# Team "Vitoria Setubal", 27 players, 12 goals
# Team "C.F. Os Belenenses", 26 players, 13 goals
# Team "Vitoria Guimaraes", 25 players, 14 goals
# Team "Sporting Braga", 31 players, 19 goals
# Team "GD Estoril Praia", 28 players, 8 goals
# Team "Feirense", 29 players, 10 goals
# Team "Nacional Funchal", 18 players, 0 goals
# Team "G.D. Chaves", 25 players, 14 goals
# [{'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/502'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164174'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2017-08-10T20:00:00Z',
#   'homeTeamName': 'Vitoria Guimaraes',
#   'matchday': 1,
#   'odds': None,
#   'result': {'goalsAwayTeam': 2,
#              'goalsHomeTeam': 3,
#              'halfTime': {'goalsAwayTeam': 0, 'goalsHomeTeam': 2}},
#   'status': 'FINISHED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/495'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164166'}},
#   'awayTeamName': 'SL Benfica',
#   'date': '2017-08-14T20:00:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 2,
#   'odds': None,
#   'result': {'goalsAwayTeam': 1,
#              'goalsHomeTeam': 0,
#              'halfTime': {'goalsAwayTeam': 0, 'goalsHomeTeam': 0}},
#   'status': 'FINISHED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/506'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164162'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2017-08-20T15:00:00Z',
#   'homeTeamName': 'Vitoria Setubal',
#   'matchday': 3,
#   'odds': None,
#   'result': {'goalsAwayTeam': 1,
#              'goalsHomeTeam': 1,
#              'halfTime': {'goalsAwayTeam': 0, 'goalsHomeTeam': 0}},
#   'status': 'FINISHED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/500'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164154'}},
#   'awayTeamName': 'Feirense',
#   'date': '2017-08-26T17:15:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 4,
#   'odds': None,
#   'result': {'goalsAwayTeam': 2,
#              'goalsHomeTeam': 0,
#              'halfTime': {'goalsAwayTeam': 1, 'goalsHomeTeam': 0}},
#   'status': 'FINISHED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/503'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164146'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2017-09-09T19:30:00Z',
#   'homeTeamName': 'FC Porto',
#   'matchday': 5,
#   'odds': None,
#   'result': {'goalsAwayTeam': 0,
#              'goalsHomeTeam': 3,
#              'halfTime': {'goalsAwayTeam': 0, 'goalsHomeTeam': 0}},
#   'status': 'FINISHED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/583'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164136'}},
#   'awayTeamName': 'Moreirense FC',
#   'date': '2017-09-18T20:00:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 6,
#   'odds': None,
#   'result': {'goalsAwayTeam': 0,
#              'goalsHomeTeam': 3,
#              'halfTime': {'goalsAwayTeam': 0, 'goalsHomeTeam': 1}},
#   'status': 'FINISHED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/582'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164128'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2017-09-23T15:00:00Z',
#   'homeTeamName': 'GD Estoril Praia',
#   'matchday': 7,
#   'odds': None,
#   'result': {'goalsAwayTeam': 2,
#              'goalsHomeTeam': 0,
#              'halfTime': {'goalsAwayTeam': 1, 'goalsHomeTeam': 0}},
#   'status': 'FINISHED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1049'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164120'}},
#   'awayTeamName': 'CD Tondela',
#   'date': '2017-09-29T19:30:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 8,
#   'odds': None,
#   'result': {'goalsAwayTeam': 1,
#              'goalsHomeTeam': 1,
#              'halfTime': {'goalsAwayTeam': 1, 'goalsHomeTeam': 1}},
#   'status': 'FINISHED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/498'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164115'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2017-10-22T19:15:00Z',
#   'homeTeamName': 'Sporting CP',
#   'matchday': 9,
#   'odds': None,
#   'result': {'goalsAwayTeam': 1,
#              'goalsHomeTeam': 5,
#              'halfTime': {'goalsAwayTeam': 0, 'goalsHomeTeam': 3}},
#   'status': 'FINISHED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/497'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164109'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2017-10-29T17:00:00Z',
#   'homeTeamName': 'Sporting Braga',
#   'matchday': 10,
#   'odds': None,
#   'result': {'goalsAwayTeam': 0,
#              'goalsHomeTeam': 1,
#              'halfTime': {'goalsAwayTeam': 0, 'goalsHomeTeam': 0}},
#   'status': 'FINISHED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/507'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164094'}},
#   'awayTeamName': 'FC Paços de Ferreira',
#   'date': '2017-11-05T17:00:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 11,
#   'odds': None,
#   'result': {'goalsAwayTeam': 2,
#              'goalsHomeTeam': 4,
#              'halfTime': {'goalsAwayTeam': 1, 'goalsHomeTeam': 1}},
#   'status': 'FINISHED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/711'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164086'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2017-11-24T20:30:00Z',
#   'homeTeamName': 'C.F. Os Belenenses',
#   'matchday': 12,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/810'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164078'}},
#   'awayTeamName': 'Boavista Porto FC',
#   'date': '2017-12-02T20:30:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 13,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1808'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164202'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2017-12-10T16:00:00Z',
#   'homeTeamName': 'Portimonense S.C.',
#   'matchday': 14,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/496'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164062'}},
#   'awayTeamName': 'FC Rio Ave',
#   'date': '2017-12-17T16:00:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 15,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/504'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164058'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2018-01-03T16:00:00Z',
#   'homeTeamName': 'Maritimo Funchal',
#   'matchday': 16,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1809'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164047'}},
#   'awayTeamName': 'Desportivo Aves',
#   'date': '2018-01-06T16:00:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 17,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/502'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164039'}},
#   'awayTeamName': 'Vitoria Guimaraes',
#   'date': '2018-01-14T16:00:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 18,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/495'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164030'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2018-01-20T16:00:00Z',
#   'homeTeamName': 'SL Benfica',
#   'matchday': 19,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/506'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164024'}},
#   'awayTeamName': 'Vitoria Setubal',
#   'date': '2018-01-31T16:00:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 20,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/500'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164017'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2018-02-04T16:00:00Z',
#   'homeTeamName': 'Feirense',
#   'matchday': 21,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/503'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164008'}},
#   'awayTeamName': 'FC Porto',
#   'date': '2018-02-11T16:00:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 22,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/583'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164001'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2018-02-18T16:00:00Z',
#   'homeTeamName': 'Moreirense FC',
#   'matchday': 23,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/582'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/163992'}},
#   'awayTeamName': 'GD Estoril Praia',
#   'date': '2018-02-25T16:00:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 24,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1049'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/163987'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2018-03-04T16:00:00Z',
#   'homeTeamName': 'CD Tondela',
#   'matchday': 25,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/498'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/163977'}},
#   'awayTeamName': 'Sporting CP',
#   'date': '2018-03-11T16:00:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 26,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/497'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/163966'}},
#   'awayTeamName': 'Sporting Braga',
#   'date': '2018-03-18T16:00:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 27,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/507'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/163963'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2018-03-31T15:00:00Z',
#   'homeTeamName': 'FC Paços de Ferreira',
#   'matchday': 28,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/711'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/163950'}},
#   'awayTeamName': 'C.F. Os Belenenses',
#   'date': '2018-04-07T15:00:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 29,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/810'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/163944'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2018-04-15T15:00:00Z',
#   'homeTeamName': 'Boavista Porto FC',
#   'matchday': 30,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1808'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/164185'}},
#   'awayTeamName': 'Portimonense S.C.',
#   'date': '2018-04-22T15:00:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 31,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/496'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/163931'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2018-04-29T15:00:00Z',
#   'homeTeamName': 'FC Rio Ave',
#   'matchday': 32,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/504'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/163918'}},
#   'awayTeamName': 'Maritimo Funchal',
#   'date': '2018-05-06T15:00:00Z',
#   'homeTeamName': 'G.D. Chaves',
#   'matchday': 33,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'},
#  {'_links': {'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1103'},
#              'competition': {'href': 'http://api.football-data.org/v1/competitions/457'},
#              'homeTeam': {'href': 'http://api.football-data.org/v1/teams/1809'},
#              'self': {'href': 'http://api.football-data.org/v1/fixtures/163912'}},
#   'awayTeamName': 'G.D. Chaves',
#   'date': '2018-05-13T15:00:00Z',
#   'homeTeamName': 'Desportivo Aves',
#   'matchday': 34,
#   'odds': None,
#   'result': {'goalsAwayTeam': None, 'goalsHomeTeam': None},
#   'status': 'SCHEDULED'}]
# [{'contractUntil': '2018-06-30',
#   'dateOfBirth': '1995-09-21',
#   'jerseyNumber': 21,
#   'marketValue': None,
#   'name': 'Jorginho',
#   'nationality': 'Portugal',
#   'position': 'Right Wing'},
#  {'contractUntil': '2020-06-30',
#   'dateOfBirth': '1989-11-03',
#   'jerseyNumber': 5,
#   'marketValue': None,
#   'name': 'Filipe Melo',
#   'nationality': 'Portugal',
#   'position': 'Defensive Midfield'},
#  {'contractUntil': '2018-06-30',
#   'dateOfBirth': '1996-05-05',
#   'jerseyNumber': 73,
#   'marketValue': None,
#   'name': 'Matheus Pereira',
#   'nationality': 'Brazil',
#   'position': 'Left Wing'},
#  {'contractUntil': '2018-06-30',
#   'dateOfBirth': '1995-03-10',
#   'jerseyNumber': 15,
#   'marketValue': None,
#   'name': 'Domingos Duarte',
#   'nationality': 'Portugal',
#   'position': 'Centre-Back'},
#  {'contractUntil': '2019-06-30',
#   'dateOfBirth': '1990-02-17',
#   'jerseyNumber': 41,
#   'marketValue': None,
#   'name': 'Rúben',
#   'nationality': 'Portugal',
#   'position': 'Left-Back'},
#  {'contractUntil': '2018-06-30',
#   'dateOfBirth': '1987-12-31',
#   'jerseyNumber': 16,
#   'marketValue': None,
#   'name': 'Djavan',
#   'nationality': 'Brazil',
#   'position': 'Left-Back'},
#  {'contractUntil': '2020-06-30',
#   'dateOfBirth': '1991-12-07',
#   'jerseyNumber': 11,
#   'marketValue': None,
#   'name': 'William',
#   'nationality': 'Brazil',
#   'position': 'Centre-Forward'},
#  {'contractUntil': '2019-06-30',
#   'dateOfBirth': '1985-04-14',
#   'jerseyNumber': 1,
#   'marketValue': None,
#   'name': 'António Filipe',
#   'nationality': 'Portugal',
#   'position': 'Keeper'},
#  {'contractUntil': '2020-06-30',
#   'dateOfBirth': '1982-07-06',
#   'jerseyNumber': 13,
#   'marketValue': None,
#   'name': 'Ricardo Nunes',
#   'nationality': 'Portugal',
#   'position': 'Keeper'},
#  {'contractUntil': '2019-06-30',
#   'dateOfBirth': '1992-08-26',
#   'jerseyNumber': 23,
#   'marketValue': None,
#   'name': 'Emanuel Novo',
#   'nationality': 'Portugal',
#   'position': 'Keeper'},
#  {'contractUntil': '2019-06-30',
#   'dateOfBirth': '1986-01-07',
#   'jerseyNumber': 14,
#   'marketValue': None,
#   'name': 'Nuno André Coelho',
#   'nationality': 'Portugal',
#   'position': 'Centre-Back'},
#  {'contractUntil': '2021-06-30',
#   'dateOfBirth': '1995-12-19',
#   'jerseyNumber': 19,
#   'marketValue': None,
#   'name': 'Nikola Maras',
#   'nationality': 'Serbia',
#   'position': 'Centre-Back'},
#  {'contractUntil': '2020-06-30',
#   'dateOfBirth': '1992-02-09',
#   'jerseyNumber': 92,
#   'marketValue': None,
#   'name': 'Victor Massaia',
#   'nationality': 'Brazil',
#   'position': 'Centre-Back'},
#  {'contractUntil': '2018-06-30',
#   'dateOfBirth': '1989-10-24',
#   'jerseyNumber': 4,
#   'marketValue': None,
#   'name': 'Anderson Conceição',
#   'nationality': 'Brazil',
#   'position': 'Centre-Back'},
#  {'contractUntil': '2018-06-30',
#   'dateOfBirth': '1994-09-20',
#   'jerseyNumber': 96,
#   'marketValue': None,
#   'name': 'Rafael Furlan',
#   'nationality': 'Brazil',
#   'position': 'Left-Back'},
#  {'contractUntil': '2018-06-30',
#   'dateOfBirth': '1984-08-08',
#   'jerseyNumber': 24,
#   'marketValue': None,
#   'name': 'Pedro Queirós',
#   'nationality': 'Portugal',
#   'position': 'Right-Back'},
#  {'contractUntil': '2020-06-30',
#   'dateOfBirth': '1988-11-03',
#   'jerseyNumber': 12,
#   'marketValue': None,
#   'name': 'Renan Bressan',
#   'nationality': 'Belarus',
#   'position': 'Central Midfield'},
#  {'contractUntil': '2019-06-30',
#   'dateOfBirth': '1988-08-31',
#   'jerseyNumber': 25,
#   'marketValue': None,
#   'name': 'Pedro Tiba',
#   'nationality': 'Portugal',
#   'position': 'Central Midfield'},
#  {'contractUntil': '2018-06-30',
#   'dateOfBirth': '1990-01-22',
#   'jerseyNumber': 8,
#   'marketValue': None,
#   'name': 'Patrão',
#   'nationality': 'Portugal',
#   'position': 'Attacking Midfield'},
#  {'contractUntil': None,
#   'dateOfBirth': '1989-08-24',
#   'jerseyNumber': 20,
#   'marketValue': None,
#   'name': 'Tiago Galvão',
#   'nationality': 'Brazil',
#   'position': 'Attacking Midfield'},
#  {'contractUntil': '2020-06-30',
#   'dateOfBirth': '1991-07-17',
#   'jerseyNumber': 10,
#   'marketValue': None,
#   'name': 'Perdigão',
#   'nationality': 'Brazil',
#   'position': 'Right Wing'},
#  {'contractUntil': '2020-06-30',
#   'dateOfBirth': '1991-03-05',
#   'jerseyNumber': 91,
#   'marketValue': None,
#   'name': 'Davidson',
#   'nationality': 'Brazil',
#   'position': 'Right Wing'},
#  {'contractUntil': '2018-06-30',
#   'dateOfBirth': '1994-02-12',
#   'jerseyNumber': 7,
#   'marketValue': None,
#   'name': 'Hamdou Elhouni',
#   'nationality': 'Libya',
#   'position': 'Right Wing'},
#  {'contractUntil': '2019-06-30',
#   'dateOfBirth': '1990-10-17',
#   'jerseyNumber': 9,
#   'marketValue': None,
#   'name': 'Jordán',
#   'nationality': 'Colombia',
#   'position': 'Centre-Forward'},
#  {'contractUntil': '2020-06-30',
#   'dateOfBirth': '1990-10-02',
#   'jerseyNumber': 99,
#   'marketValue': None,
#   'name': 'Platiny',
#   'nationality': 'Brazil',
#   'position': 'Centre-Forward'}]

# %%
def get_age(birth_raw):
    now = datetime.datetime.today()
    birth = datetime.datetime.strptime(birth_raw, '%Y-%m-%d')
    age_raw = now - birth
    age = age_raw.days / 365
    return age

# %%
for team in teams:
    players = call_api(team['_links']['players']['href'], 'players')
    fixtures = call_api(team['_links']['fixtures']['href'], 'fixtures')
    age_list = []
    for player in players:
        age = get_age(player['dateOfBirth'])
        age_list.append(age)
    average_age = sum(age_list) / len(age_list)
    loses = 0
    for f in fixtures:
        if team['name'] == f['homeTeamName']:
            if f['result']['goalsAwayTeam'] == f['result']['goalsHomeTeam']:
                continue
            elif f['result']['goalsAwayTeam'] > f['result']['goalsHomeTeam']:
                loses += 1
            else:
                continue
        else:
            if f['result']['goalsAwayTeam'] == f['result']['goalsHomeTeam']:
                continue
            elif f['result']['goalsAwayTeam'] < f['result']['goalsHomeTeam']:
                loses += 1
            else:
                continue
    print('Team "{}", {} average age, {} loses'.format(team['name'], average_age, loses))
    team['average_age'] = average_age
    team['loses'] = loses
# Out:
# Team "FC Rio Ave", 25.520446473871136 average age, 4 loses
# Team "FC Porto", 27.04394520547944 average age, 2 loses
# Team "Moreirense FC", 24.962524461839536 average age, 6 loses
# Team "FC Paços de Ferreira", 26.494731296101158 average age, 5 loses
# Team "Sporting CP", 26.272349061390166 average age, 2 loses
# Team "Maritimo Funchal", 26.410014170996696 average age, 3 loses
# Team "CD Tondela", 26.03074581430745 average age, 5 loses
# Team "SL Benfica", 26.23411400795405 average age, 5 loses
# Team "Boavista Porto FC", 25.557052943354318 average age, 6 loses
# Team "FC Arouca", 27.56973848069739 average age, 0 loses
# Team "Vitoria Setubal", 25.86707255200406 average age, 5 loses
# Team "C.F. Os Belenenses", 27.075342465753426 average age, 5 loses
# Team "Vitoria Guimaraes", 25.359013698630136 average age, 5 loses
# Team "Sporting Braga", 24.885903667697743 average age, 3 loses
# Team "GD Estoril Praia", 24.360371819960864 average age, 9 loses
# Team "Feirense", 25.927066603684462 average age, 6 loses
# Team "Nacional Funchal", 26.503348554033483 average age, 0 loses
# Team "G.D. Chaves", 27.2106301369863 average age, 6 loses

# %%
team_for_pd = []
for team in teams:
    if team['players']:
        team_for_pd.append({'name': team['name'], 'average_age': team['average_age'], 'loses': team['loses']})
team_for_pd
# Out:
# [{'average_age': 25.520446473871136, 'loses': 4, 'name': 'FC Rio Ave'},
#  {'average_age': 27.04394520547944, 'loses': 2, 'name': 'FC Porto'},
#  {'average_age': 24.962524461839536, 'loses': 6, 'name': 'Moreirense FC'},
#  {'average_age': 26.494731296101158,
#   'loses': 5,
#   'name': 'FC Paços de Ferreira'},
#  {'average_age': 26.272349061390166, 'loses': 2, 'name': 'Sporting CP'},
#  {'average_age': 26.410014170996696, 'loses': 3, 'name': 'Maritimo Funchal'},
#  {'average_age': 26.03074581430745, 'loses': 5, 'name': 'CD Tondela'},
#  {'average_age': 26.23411400795405, 'loses': 5, 'name': 'SL Benfica'},
#  {'average_age': 25.557052943354318, 'loses': 6, 'name': 'Boavista Porto FC'},
#  {'average_age': 27.56973848069739, 'loses': 0, 'name': 'FC Arouca'},
#  {'average_age': 25.86707255200406, 'loses': 5, 'name': 'Vitoria Setubal'},
#  {'average_age': 27.075342465753426, 'loses': 5, 'name': 'C.F. Os Belenenses'},
#  {'average_age': 25.359013698630136, 'loses': 5, 'name': 'Vitoria Guimaraes'},
#  {'average_age': 24.885903667697743, 'loses': 3, 'name': 'Sporting Braga'},
#  {'average_age': 24.360371819960864, 'loses': 9, 'name': 'GD Estoril Praia'},
#  {'average_age': 25.927066603684462, 'loses': 6, 'name': 'Feirense'},
#  {'average_age': 26.503348554033483, 'loses': 0, 'name': 'Nacional Funchal'},
#  {'average_age': 27.2106301369863, 'loses': 6, 'name': 'G.D. Chaves'}]

# %%
teams_pd = pd.DataFrame(team_for_pd)
del teams_pd['name']
teams_pd
# Out:
#     average_age  loses
# 0     25.520446      4
# 1     27.043945      2
# 2     24.962524      6
# 3     26.494731      5
# 4     26.272349      2
# 5     26.410014      3
# 6     26.030746      5
# 7     26.234114      5
# 8     25.557053      6
# 9     27.569738      0
# 10    25.867073      5
# 11    27.075342      5
# 12    25.359014      5
# 13    24.885904      3
# 14    24.360372      9
# 15    25.927067      6
# 16    26.503349      0
# 17    27.210630      6

# %%
whitened = whiten(teams_pd.as_matrix())
whitened
# Out:
# array([[ 30.32712814,   1.81307867],
#        [ 32.13757222,   0.90653934],
#        [ 29.66412358,   2.71961801],
#        [ 31.4849159 ,   2.26634834],
#        [ 31.22064879,   0.90653934],
#        [ 31.38424262,   1.35980901],
#        [ 30.93354047,   2.26634834],
#        [ 31.17521231,   2.26634834],
#        [ 30.3706293 ,   2.71961801],
#        [ 32.76239671,   0.        ],
#        [ 30.73903995,   2.26634834],
#        [ 32.17488304,   2.26634834],
#        [ 30.1352901 ,   2.26634834],
#        [ 29.57307154,   1.35980901],
#        [ 28.94855771,   4.07942702],
#        [ 30.81033366,   2.71961801],
#        [ 31.49515619,   0.        ],
#        [ 32.33565164,   2.71961801]])

# %%
centroids, cluster_map = kmeans2(whitened, 5)
centroids, cluster_map
# Out:
# (array([[ 32.25526734,   2.49298318],
#         [ 32.13170837,   0.30217978],
#         [ 31.30244571,   1.13317417],
#         [ 31.02860846,   2.35700228],
#         [ 29.83646673,   2.49298318]]),
#  array([4, 1, 4, 3, 2, 2, 3, 3, 4, 1, 3, 0, 4, 4, 4, 3, 1, 0]))

# %%
colors_map = {0: 'r', 1: 'g', 2: 'b', 3: 'y', 4: 'm'}
colors = [colors_map[c] for c in cluster_map]
colors
# Out:
# ['m',
#  'g',
#  'm',
#  'y',
#  'b',
#  'b',
#  'y',
#  'y',
#  'm',
#  'g',
#  'y',
#  'r',
#  'm',
#  'm',
#  'm',
#  'y',
#  'g',
#  'r']

# %%
teams_pd.plot.scatter(x='average_age', y='loses', c=colors, s=100)

# %% [markdown]
# 3 кластера

# %%
centroids, cluster_map = kmeans2(whitened, 3)
centroids, cluster_map
# Out:
# (array([[ 31.79266572,   2.37966576],
#         [ 31.80000331,   0.63457754],
#         [ 30.16685716,   2.46780153]]),
#  array([2, 1, 2, 0, 1, 1, 2, 0, 2, 1, 2, 0, 2, 2, 2, 2, 1, 0]))

# %%
colors_map = {0: 'r', 1: 'g', 2: 'b'}
colors = [colors_map[c] for c in cluster_map]
colors
# Out:
# ['b',
#  'g',
#  'b',
#  'r',
#  'g',
#  'g',
#  'b',
#  'r',
#  'b',
#  'g',
#  'b',
#  'r',
#  'b',
#  'b',
#  'b',
#  'b',
#  'g',
#  'r']

# %%
teams_pd.plot.scatter(x='average_age', y='loses', c=colors, s=100)
